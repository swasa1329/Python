# %% [markdown]
# ###### What Are Decision Making Statements?

# %%
Decision-making statements are those that help in deciding the flow of the program. 

For example, at times, you might want to execute a block of code only if a particular condition is satisfied.

Well, in this case, decision-making statement will be of great help. 

Let us consider an example to understand this better.

Suppose you are given a number and are asked to check if it is an even number or not. How would you do it?

The first thought that would pop up your mind is this - 

"If the number is divisible by 2, then it is an even number, else it is an odd number". 
That's absolutely the right logic. 
But when this has to be coded, you will need the help of decision-making statements.

# %%
# Python supports the usual logical conditions from mathematics:

# Equals: a == b
# Not Equals: a != b
# Less than: a < b
# Less than or equal to: a <= b
# Greater than: a > b
# Greater than or equal to: a >= b

# These conditions can be used in several ways, most commonly in "if statements" and loops.

# An "if statement" is written by using the if keyword.

# %% [markdown]
# ###### if statement

# %%
This is the simplest decision-making statement in Python.
It is used to decide if a particular block of code needs to be executed or not.
Whenever the given condition is True, then the block of code inside it gets executed, else it does not.

# %%
The if statement flowchart:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### The syntax for if statement:

# %%
An if statementshould be preceded by the keyword if and ended with a colon :. 
    
The condition of an if statement can be written with or without round brackets.

# Use (:) operator  at the end of the if line,because whatever the code you write after 
# the colon operator will be part of if block

# %%
a=100
b=200

if b>a:
    print("b is greater than a") # in Python indentation should follow

# %%
# Note:- If statement, without indentation (will raise an error):

passmarks=50
myscore=70
if myscore >= passmarks: 
    print("Passed")

# %% [markdown]
# ###### if...else

# %%
The statements written within the else block get executed whenever the if condition is False.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### The syntax for if else statement:

# %%
Else statement is preceded by the keyword 'else' and it also ends with a colon :. 
Unlike the if, the else statement will not have any conditional statements.
--------------
if condition:
   body of if
else:
   body of else

# %%
x=100
y=200

if x>y:
    print("X is Greater Than Y")
else:
    print("X is Not Greater Than Y")

# %%
x=float(input("Value of x:- "))
y=float(input("Value of y:- "))

print("x Value is: ", x)
print("y Value is: ", y)

print()

if x>y:
    print("x is Greater Than y")
else:
    print("y is Greater Than x")

# %% [markdown]
# ###### If-Else with same values

# %%
#program to check if num1 is less than num2

num1 =5
num2 = 5

if (num1 < num2):
    print("num1 is less than num2")
else:
    print("num2 is less than num1")
    
# Output: num2 is lesser than num1

# %% [markdown]
# ###### Why was the output wrong?

# %%
Since both the input values are equal, the condition num1<num2 is False. 
So immediately the control shifts to else block and the print statement inside it gets executed.
However, this is not logically correct as both the input values are equal (5 = 5).

# %% [markdown]
# ###### How to rectify this?

# %%
Your program should logically include every possible test case and 
only then your program will produce accurate results. 
So this mean you need to add another conditional statement to check if num1 is equal to num 2. 

Let us now see how this can be done.

# %% [markdown]
# ###### elif statement

# %%
The keyword elif is a combination of else and if.
This statement works similar to 'else if' statements in the C and other languages. 
The statements in elif block get executed when the previous if condition is False.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### The syntax for elif statement:

# %%
if condition:
 body of if
elif condition:
 body of elif
else:
 body of else

# %%
num1 =5
num2 = 5

if(num1 > num2):
  print("num1 is greater than num2")
elif(num1 == num2):
  print("num1 is equal to num2")
else:
  print("num1 is less than num2")

# Output:num1 is equal to num2

# Explanation: Since both the values are equal, the if condition is False.
# Now the control shifts to elif statement and here the condition is True. 
# Hence the statements in the elif block get executed.

# %%
x=float(input("Value of x:- "))
y=float(input("Value of y:- "))

print("x Value is: ", x)
print("y Value is: ", y)

print()

if x>y:    
    print("x is Greater Than y")
elif y<x:
    print("y is Less Than x")
else:
    print("Given Values are Equal")

# %%
# 10, 50, 100 other than these 3 values..msg should be not in the list

x=int(input("Value of x:- "))

if x==10:
    print("Your Input Values is: ", x)
elif x==50:
    print("Your Input Values is: ", x)
elif x==100:
    print("Your Input Values is: ", x)
else:
    print("Your Input Values are not in the List of 10, 50 & 100: ")

# %%
# Which is the largest Value in the given 3 input values

x=int(input("Value of x:- "))
y=int(input("Value of y:- "))
z=int(input("Value of z:- "))

print("Given Input Values Are:- ", x,y,z)

if x>y and x>z:
    print("x is Greater Than y and z ", x)
elif y>x and y>z:
    print("y is Greater Than x and z ", y)
else:
    print("z is Greater Than x and y ", z)

# %%
# Prob-1: 
# Student Marks, 90 to 100- grade A, 
# Student Marks, 70 to 90- grade B, 
# Student Marks, 50 to 70- grade C, 
# Student Marks, 35 to 50- grade D, 
# Student Marks, Below 35- grade E,

# %% [markdown]
# Let's say you are given a time and you have to tell what phase of the day it is- (morning, noon, afternoon, evening or night).
# You will have to check the given time against multiple ranges of time within which each of the 5 phases lies.
# Therefore, the following conditions:
#
# 1.	Morning: 0600 to 1159
# 2.	Noon: 1200
# 3.	Afternoon: 1201 to 1700
# 4.	Evening: 1701 to 2000
# 5.	Night: 2000 to 0559

# %%
M=int(input("Enter the Time:- "))

if M>=600 and M<1200:
    print("Good Morning - Your's is Morning Shift")
elif M==1200:
    print("Good Noon - Your's is Noon Shift")
elif M>=1201 and M<=1700:
    print("Good AfterNoon - Your's is AfterNoon Shift")
elif M>=1701 and M<=2000:
    print("Good Evenin - Your's is Evening Shift")
elif M>2000 and M<2400 or M>=0 and M<=559:
    print("Good Night - Your's is Night Shift")
else:
     print("Please Entered With in the Time Limit")

# %%
# menus
print("Calculator")
print("1.Add")
print("2.Substract")
print("3.Multiply")
print("4.Divide")
print()
# input choice
ch=int(input("Enter Choice(1-4): "))

if ch==1:
    a=int(input("Enter A:"))
    b=int(input("Enter B:"))
    c=a+b
    print("Sum = ",c)
elif ch==2:
    a=int(input("Enter A:"))
    b=int(input("Enter B:"))
    c=a-b
    print("Difference = ",c)
elif  ch==3:
    a=int(input("Enter A:"))
    b=int(input("Enter B:"))
    c=a*b
    print("Product = ",c)
elif ch==4:
    a=int(input("Enter A:"))
    b=int(input("Enter B:"))
    c=a/b
    print("Quotient = ",c)
else:
    print("Invalid Choice")

# %% [markdown]
# ###### Check If Item Present in a Sequence

# %%
L = ['red', 'green', 'blue']

if 'red' in L:
    print('Red is present in the List')

# tuple
T = ('red', 'green', 'blue')
if 'red' in T:
    print('yes')
# Prints yes

# string
S = 'Hello, World!'
if 'Hello' in S:
    print('Yes')
# Prints yes

# %% [markdown]
# ###### Discount Program

# %%
price=int(input("Enter price:- "))
qty=int(input("Enter quantity:- "))

amt=price*qty

if amt>10000:
   print ("10% discount applicable")
   discount=amt*10/100
   amt=amt-discount
elif amt>5000:
   print ("5% discount applicable")
   discount=amt*5/100
   amt=amt-discount
elif amt>2000:
   print ("2% discount applicable")
   discount=amt*2/100
   amt=amt-discount
elif amt>1000:
   print ("1% discount applicable")
   discount=amt/100
   amt=amt-discount
else:
   print ("no discount applicable")

print ("amount payable:",amt)

# %%
Price = int(input("Enter the Price:"))
Quantity = int(input("Enter the Quantity:"))

print()

Amount=Price*Quantity

print("Original Amount",Amount)

print()

if Amount >=10000:
    print("20% Discount is Applicable",Amount*0.2,"\n")
    print("Total Payable Amount",Amount-(Amount*0.2),"\n")

elif Amount >= 5000 and Amount <= 9999:
    print("15% Discount is Applicable",Amount*0.15,"\n")
    print("Total Payable Amount",Amount-(Amount*0.15),"\n")

elif Amount >= 2000 and Amount <= 4999:
    print("10% Discount is Applicable",Amount*0.10,"\n")
    print("Total Payable Amount",Amount-(Amount*0.10),"\n")
    
elif Amount >= 1000 and Amount <= 1999:
    print("5% Discount is Applicable",Amount*0.05,"\n")
    print("Total Payable Amount",Amount-(Amount*0.05),"\n")
    
elif Amount > 1 and Amount <=999:
    print("No Discount Applicable","\n","Total Amount Payable:",Amount)

else:
    print("Enter Valid Details")

# %% [markdown]
# ###### Guess Program

# %%
number = 20

guess = int(input('Enter an integer : '))

if guess == number:
    print('Congratulations, you guessed it.')

elif guess < number:
    print('No, it is a little higher than that')

else:
    print('No, it is a little lower than that')

# %% [markdown]
# ###### Password Validation

# %%
password = 'Mission'

if len(password) < 6:
    print('password too weak - should be at least 6 characters')
else:
    print('your password was accepted')

# %% [markdown]
# ###### Equilateral triangle

# %%
a = 5
b = 5
c = 5

if a != b and b != c and a != c:
    print('This is a scalene triangle')
elif a == b and b == c:
    print('This is an equilateral triangle')
else:
    print('This is an isosceles triangle')

# %% [markdown]
# ###### elif with current day

# %%
import datetime
  
currday = datetime.date.today()

print("Current date:-",currday)
 
w = currday.weekday() + 1
print(w)

# w = int(input("Enter the day:-"))
 
if (w == 0): 
    print("Its Sunday.");
 
elif (w == 1): 
    print("The first working day, Monday!");
 
elif (w == 2):
    print("The second working day, Tuesday!");
 
elif (w == 3): 
    print("The third working day, Wed!");
 
elif (w == 4): 
    print("Weekend is getting closer, its Thu!");
 
elif (w == 5): 
    print("Hurray! so close, its Fri!");
 
else: 
    print("Yay, the Weekend started, as its Sat!");

# %%
# Program to display given letter is an vowel or consonent

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Which Year is the LEAP Year or Not

cy = int(input("Enter the year:-"))
m = int(input("Enter the month:"))
if (cy % 4) == 0 and (cy % 100) == 0 or (cy % 400) == 0:
    print("Leap Year")
    if m == 1 or m == 3 or m == 5 or m == 7 or m == 8 or m == 10 or m == 12:
        print("There are 31 days in this month")
    elif m == 4 or m == 6 or m == 9 or m == 11:
        print("There are 30 days in this month")
    elif m == 2:
        print("There are 29 days in this month")
    else:
        print("Invalid Month")
elif (cy % 4) != 0 or (cy % 100) != 0 or (cy % 400) != 0:
    print("Non Leap Year")
    if m == 1 or m == 3 or m == 5 or m == 7 or m == 8 or m == 10 or m == 12:
        print("There are 31 days in this month")
    elif m == 4 or m == 6 or m == 9 or m == 11:
        print("There are 30 days in this month")
    elif m == 2:
        print("There are 28 days in this month")
    else:
        print("Invalid Month")
else:
    print("Invalid Year")
