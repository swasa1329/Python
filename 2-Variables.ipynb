# %% [markdown]
# ###### Print()

# %%
print('This is my First Python program')
# Out:
# This is my First Python program

# %% [markdown]
# ###### Comment

# %%
To make single line comment :- use # symbol. 

To make multiple line comments :- use ctrl + /

# %% [markdown]
# ###### VALUES - STORE IN VARIABLES

# %%
Values are basic thing in any program. 

Values can be different types, it can be of integer types or floating types or strings.

The values which are enclosed within the single quotes or double quotes are called as strings

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### Variables

# %%
Variables are defined as name given to some value or information.

For Ex:- X=16. Here 16 is value and 'X' is the name given to that value. so here 'X' is a variable. 

To create a variable and name the variable, we use assignment operator(=).

Variable name will be present on left side of the assignment operator and 
the value will be present on right side of the assignment operator.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
X=10

Y=20.5

S='HELLO'

# %%
Why we name as variable beacuse as name indicates it is not constant.
It's keep on changing.

For Example, x=10 doesnot mean that always x value will be 10.
it can be changed.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# A variable is created the moment you first assign a value to it.

X=50

Y='HELLO'

print(X,Y)

# %%
#### Variables are containers for storing data values
# A variable is created the moment you first assign a value to it.

x=10
y=20.5
z="KAIS-IT"

print(x)
print(y)
print(z)

print()

print("The Value in X :-" ,x)
print("The Value in y :-" ,y)
print("The Value in z :-" ,z)

print()

print('Data type of x value :- ',type(x))
print('Data type of y value :- ',type(y))
print('Data type of z value :- ',type(z))

# %% [markdown]
# ###### Rules for Variable Names

# %%
# A variable can have a short name (like x and y) or a more descriptive name (age, carname, total_volume).

# A variable name must start with a letter or the underscore character.

# A variable name cannot start with a number.

# A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ ).

# Variable names are case-sensitive (age, Age and AGE are three different variables).

# %% [markdown]
# ###### Legal Variable Names

# %%
name="Python"
print(name)
print()

my_name="Data_Sciences"
print(my_name)
print()

_my_name="Machine-Learning"
print(_my_name)
print()

myName="NumPy"
print(myName)
print()

myname_2="Pandas"
print(myname_2)
print()

myname3="Matplotlib"
print(myname3)
print()

MYNAME="Searborn"
print(MYNAME)
# Out:
# Python
#
# Data_Sciences
#
# Machine-Learning
#
# NumPy
#
# Pandas
#
# Matplotlib
#
# Searborn

# %% [markdown]
# ###### Invalid Variable Names

# %%
2myname=10

print(2myname)

# %%
My-Name="PowerBI"

print(My-Name)

# %%
my name="Tableau"

print(my name)

# %% [markdown]
# ###### Assign value to multiple variables

# %%
x="Python"
y="DA"
z="DS"

print(x)
print(y)
print(z)

# %% [markdown]
# ###### Python allows you to assign values to multiple variables in one line:

# %%
x,y,z="Phython","DA","DS"

print(x,y,z)
print()

print(x,"\n",y,"\n",z)

print(x,",",y,",",z)
# Out:
# Phython DA DS
#
# Phython
#  DA
#  DS
# Phython , DA , DS

# %%
# x,y,z="Python","DA","DS"

# print(x,y,z)
# print()

# # print("",x,'\n',y,"\n",z)
# Out:
# Python DA DS
#
#  Python
#  DA
#  DS
# Python , DA , DS

# %% [markdown]
# ###### we can assign the same value to multiple variables in one line:

# %%
x=y=z="Python"

print(x)
print(y)
print(z)

# %% [markdown]
# ###### Re-declare variables

# %%
a=50

print("Original value in the variable:- ",a)

a=100

print("Re-declaring variable with new value:- ",a)

# %% [markdown]
# ###### Output Variables

# %%
# The Python print statement is often used to output variables.

# To combine both text and a variable, Python uses the + character

# %%
x="easy to learn"

print("Python is " + x)

# %%
x="easy to learn "
y="easy to execute"

print("Python is " +x +y)
print("Python is " +x, ""+y)

# %% [markdown]
# ###### Exercise

# %%
# 1. Create a variable named vechile and assign the value Audi to it.

# 2. Create a variable named x and assign the value 50 to it.

# 3. Display the sum of 5 + 10, using two variables: x and y.

# 4. Create a variable called z, assign x + y to it, and display the result. Here x=100, y=200

# 5. Remove the illegal characters in the variable name: 5my-first_name = "Prince"

# 6. Insert the correct syntax to assign the same value to all three variables in one code line. 
     # variables here are x,y,z and value will be 100.

# %%
vehicle="Audi"
print("The value in variable is:-",vehicle)

x=50
print("The value in variable x is:-",x)

x=5
y=10
print("Sum of x and y is :-", x + y)
print()

x=100
y=200
z=x+y
print("Value of z :- ", z)

print()
x=y=z=100
print(x,y,z)

print()
my_first_name="Prince"
print(my_first_name)

# %%
x=50
y=100
z=200

print("Sum of x,y and z :- " ,x+y+z)

print()

print("Average of x,y and z :- " ,(x+y+z)/3)

# %%
# Another way :- 

x=50
y=100
z=200

sum=x+y+z
print("Sum of x,y and z :- " ,sum)

print()

avg=sum/3
print("Average of x,y and z :- " ,avg)

# %% [markdown]
# ###### To know the Data Type

# %%
x=100

y=100.25

z='python'

a=True

b=False

#To know the type of the Variable,we use type() method

print("The Data type of x is :-", type(x),"\n")
print("The Data type of y is :-", type(y),"\n")
print("The Data type of z is :-", type(z),"\n")
print("The Data type of a is :-", type(a),"\n")
print("The Data type of b is :-", type(b),"\n")

# %% [markdown]
# ###### Delete Variable DEL

# %%
a=10
print(a)

del a #deleting a variable

print(a)

# %% [markdown]
# ###### Strings:- Single & Double quotes

# %%
##print('It's Python')

# It gives an invalid syntax error. Because single quote after “it” is considered as the end of the string
# and rest part is not the part of a string.
# It can be corrected as

print("It's Python")

# %%
print("'Python-Program'")

# %%
print("Hello 'Python'")

# %%
print('"Data-Analytics"')

# %%
print('Hello "Python"')

# %% [markdown]
# ###### Control Characters \n - new line and \t - tab

# %%
#Control Characters are the characters which controls the output

# \n - print in Newline

print("Hello World! Welcome to Leena-IT Services Pvt. Ltd")
print()
print("Hello World!" "\n" "Welcome to Leena-IT Services Pvt. Ltd")
print()
print("Hello World! \nWelcome to Leena-IT Services Pvt. Ltd")
print()
print("Hello World! \n Welcome to Leena-IT Services Pvt. Ltd")
print()

# \t - Tab Space

print("Hello World! \t Welcome to Leena-IT Services Pvt. Ltd")
print()
print("Hello World! \nWelcome to Leena-IT \t Services Pvt. Ltd")
print()
print("Hello World! \t Welcome to Leena-IT \t Services Pvt. Ltd")

# %%
print("Hello world! Welcome to Data Analytics Training Program")

# %%
print("Hello world! \nWelcome to Data Analytics Training Program")

# %%
print("Hello world!\n" "Welcome to Data Analytics Training Program")

# %%
print("Hello world! \nWelcome to Data Analytics \t Training Program")

# %% [markdown]
# ###### Data Type: Boolean - Bool()

# %%
# Returns False as x is False

x=False
print(bool(x))

# Returns True as y is True
y=True
print(bool(y))

x=5
y=10
print(bool(x==y))

# %% [markdown]
# ###### Concatenation

# %%
#we can concat two same data types, but we cannot concat two different data types

x=10
y=20

print("The concatenation of integers x and y is :-", x+y)

print()

x=10.5
y=20.4

print("The concatenation of float values x and y is :-", x+y)

print()

x= "'Hello\t"
y= "World'"

print("The concatenation of String values x and y is :-", x+y)

print()

x=10
y=20.5

print("The concatenation of integer x and float y is :-", x+y)

# %%
x=True
y=5

print("The concatenation of boolean True with integer is :-", x+y,"\n")

x=False
y=10

print("The concatenation of boolean False with integer is :-", x+y, "\n")

x=True
y=True

print("The concatenation of boolean True with True is :-", x+y, "\n")

x=False
y=False

print("The concatenation of boolean False with False is :-", x+y, "\n")

x=True
y=False

print("The concatenation of boolean True with False is :-", x+y)

# %%
x=10
y="Hello"

print("The concatenation of integer with String is :-", x+y)

# %%
x=10.10
y="Hello"

print("The concatenation of float with String is :-", x+y)

# %%
x=True
y="Hello"

print("The concatenation of boolean with String is :-", x+y)

# %% [markdown]
# ###### User Inputs - Input Method

# %%
x=10
y=20

z=x+y

print("Addition of two numbers:- " ,z)
# Out:
# Addition of two numbers:-  30

# %%
x=input("Enter the first number:-")
y=input("Enter the second number:-")

z=x+y # By default, input() method will consider all values as strings.

print("Addition of two numbers:- ", z)
# Out:
# Enter the first number:-4
# Enter the second number:-6
# Addition of two numbers:-  46

# %% [markdown]
# ###### Data Type Conversion

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x=int(input("Enter the first number:-"))

y=int(input("Enter the second number:-"))

z=x+y # By default, input() method will consider all values as strings.

print("Addition of two numbers:- " ,z)

# %%
 # By default, input() method will consider all values as strings.
    
# We need to typecast. Typecast is used to convert strings to integers.

x=input("Enter the first number:-")

y=input("Enter the second number:-")

z=int(x)+int(y) # Typecasting

print("Addition of two numbers:- " ,z)

# %%
# Addition of two Float numbers

x=float(input("Enter the first decimal number:-"))

y=float(input("Enter the second decimal number:-"))

z=x+y # By default, input() method will consider all values as strings.

print("Addition of two numbers:- " ,z)

# %%
Addition of two Float numbers in other way

x=input("Enter the first decimal number:-")

y=input("Enter the second decimal number:-")

z=float(x)+float(y) 

print("Addition of two numbers:- " ,z)

# %%
# Addition of INT + FLOAT

x=input("Enter First Number:- ")

y=input("Enter Second Number:- ")

z= int(x)+float(y)

print("Addition of two numbers",z )
# Out:
# Enter First Number:- 5
# Enter Second Number:- 6.5
# Addition of two numbers 11.5

# %%
num1 = input("Enter First Decimal Number:-")

num2 = input("Enter Second Decimal Number:-")

z = float(num1)+int(num2)  # VALUE ERROR: INVALID LITERAL FOR int()

print("Addition of two numbers:-",z)

# Note:- Float can hold integers, but integers cannot hold float.
# Out:
# Enter First Decimal Number:-5
# Enter Second Decimal Number:-6
# Addition of two numbers:- 11.0

# %% [markdown]
# ###### Keywords

# %%
import keyword

print(keyword.kwlist) #prints all the keywords supported by python3

# %%
help('keywords')

# %% [markdown]
# ###### Python Indentation

# %%
# Indentation refers to the spaces at the beginning of a code line.
# Where in other programming languages the indentation in code is for readability only, 
# the indentation in Python is very important.
# Python uses indentation to indicate a block of code.

# %%
x=5
y=10

if (x<y):
 print('x is lessthan y')

# %%
if 5 > 2:
  print("Five is greater than two!")

# %% [markdown]
# ###### Swapping

# %%
x=10
y=20

print("Before swapping:-")
print()
print("x =",x)
print("y =",y)

x,y=y,x

print()

print("After swapping:-")
print()
print("x =",x)
print("y =",y)

# %%
x=10
y=20

print("values before swapping")
print()
print()
print("the value of x=",x)
print("the value of y=",y)
x,y=y,x
print()
print("values after swapping")
print()
print("the value of x=",x)
print("the value of y=",y)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
1. Write a program in Python language that asks the user to enter their name and display their name with a welcome message!
